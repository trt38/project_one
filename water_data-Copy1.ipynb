# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
#from scipy.stats import linregress

#Dont' forget PNG of datframs
census_data = "../project_one/census_income_data.csv"

# %%
#Obtaining data from csv and api
#census_data_income = pd.read_csv(census_data)
#census_data_income

# https://enviro.epa.gov/enviro/efservice/SDW_VIOL_ENFORCEMENT/COUNTYSERVED/MCLEAN/STATE/IL/Excel
    
url = "https://enviro.epa.gov/enviro/efservice/SDW_VIOL_ENFORCEMENT/CSV"

response = requests.get(url).json
print(response)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
CSV_URL = "https://enviro.epa.gov/enviro/efservice/SDW_VIOL_ENFORCEMENT/CSV" 
#requesting csv from epa website decoding/reading as csv then converting to a list    
with requests.Session() as s:
    download = s.get(CSV_URL)

    decoded_content = download.content.decode('utf-8')

    cr = csv.reader(decoded_content.splitlines(), delimiter=',')
    my_list = list(cr)
    
# Converting to dataframe    
epa_csv = pd.DataFrame(my_list)
epa_csv
# Out:
#                                 0                               1   \
# 0       SDW_VIOL_ENFORCEMENT.PWSID    SDW_VIOL_ENFORCEMENT.PWSNAME
# 1                        ID5160056                SPRINGDALE ACRES
# 2                        IN2493152     G & S REALTY PARTNERS, LLC.
# 3                        PA2450314              FEDEX FREIGHT EAST
# 4                        WY5601199     KENNINGTON SPRINGS PIPELINE
# ...                            ...                             ...
# 99997                    CT0650102  HARTLAND ELEM SCH & TOWN BLDGS
# 99998                    WV3305535         HERNDON COMMUNITY WATER
# 99999                    VA6047255            GLENDALE SUBDIVISION
# 100000                   MA1033000            BLANDFORD WATER DEPT
# 100001                   ID2250026         HARPSTER WATER DISTRICT
#
#                                 2                                  3   \
# 0       SDW_VIOL_ENFORCEMENT.STATE  SDW_VIOL_ENFORCEMENT.COUNTYSERVED
# 1                               ID                             CASSIA
# 2                               IN                             MARION
# 3                               PA                             MONROE
# 4                               WY
# ...                            ...                                ...
# 99997                           CT
# 99998                           WV
# 99999                           VA                           CULPEPER
# 100000                          MA
# 100001                          ID                              IDAHO
#
#                                 4                           5   \
# 0       SDW_VIOL_ENFORCEMENT.VIOID  SDW_VIOL_ENFORCEMENT.CCODE
# 1                             8251                        2274
# 2                             6030                        2992
# 3                          1016111                        2992
# 4                             2325                        2046
# ...                            ...                         ...
# 99997                       379909                        2990
# 99998                      5204831                        2990
# 99999                           63                        2990
# 100000                          10                        2990
# 100001                       20308                        2990
#
#                                 6                           7   \
# 0       SDW_VIOL_ENFORCEMENT.CNAME  SDW_VIOL_ENFORCEMENT.CTYPE
# 1                HEXACHLOROBENZENE                         SOC
# 2                     Ethylbenzene                         VOC
# 3                     Ethylbenzene                         VOC
# 4                       Carbofuran                         SOC
# ...                            ...                         ...
# 99997                      Benzene                         VOC
# 99998                      Benzene                         VOC
# 99999                      Benzene                         VOC
# 100000                     Benzene                         VOC
# 100001                     Benzene                         VOC
#
#                                 8                           9   ...  \
# 0       SDW_VIOL_ENFORCEMENT.VCODE  SDW_VIOL_ENFORCEMENT.VNAME  ...
# 1                               03         Monitoring, Regular  ...
# 2                               03         Monitoring, Regular  ...
# 3                               03         Monitoring, Regular  ...
# 4                               03         Monitoring, Regular  ...
# ...                            ...                         ...  ...
# 99997                           03         Monitoring, Regular  ...
# 99998                           03         Monitoring, Regular  ...
# 99999                           03         Monitoring, Regular  ...
# 100000                          03         Monitoring, Regular  ...
# 100001                          03         Monitoring, Regular  ...
#
#                                       11                                  12  \
# 0       SDW_VIOL_ENFORCEMENT.VIOLMEASURE  SDW_VIOL_ENFORCEMENT.ENFACTIONTYPE
# 1               Monitoring and Reporting                                 SIF
# 2               Monitoring and Reporting                                 SIF
# 3               Monitoring and Reporting                                 SIA
# 4               Monitoring and Reporting                                 SOX
# ...                                  ...                                 ...
# 99997           Monitoring and Reporting                                 SIE
# 99998           Monitoring and Reporting                                 SIE
# 99999           Monitoring and Reporting                                 SIE
# 100000          Monitoring and Reporting                                 SFL
# 100001          Monitoring and Reporting                                 SOX
#
#                                         13                            14  \
# 0       SDW_VIOL_ENFORCEMENT.ENFACTIONNAME  SDW_VIOL_ENFORCEMENT.ENFDATE
# 1                 St Public Notif received                     18-JUN-14
# 2                 St Public Notif received                     10-JUN-10
# 3             St Violation/Reminder Notice                     25-AUG-10
# 4                   St Compliance achieved                     24-OCT-11
# ...                                    ...                           ...
# 99997            St Public Notif requested                     09-MAR-09
# 99998            St Public Notif requested                     13-FEB-14
# 99999            St Public Notif requested                     16-DEC-09
# 100000          St AO (w/o penalty) issued                     07-NOV-14
# 100001              St Compliance achieved                     19-MAR-10
#
#                                            15  \
# 0       SDW_VIOL_ENFORCEMENT.COMPPERBEGINDATE
# 1                                   01-JAN-11
# 2                                   01-JAN-09
# 3                                   01-APR-10
# 4                                   01-JAN-08
# ...                                       ...
# 99997                               01-OCT-08
# 99998                               01-OCT-13
# 99999                               01-JAN-09
# 100000                              01-JUL-14
# 100001                              01-JAN-05
#
#                                          16  \
# 0       SDW_VIOL_ENFORCEMENT.COMPPERENDDATE
# 1                                 31-DEC-13
# 2                                 31-DEC-09
# 3                                 30-JUN-10
# 4                                 31-DEC-10
# ...                                     ...
# 99997                             31-DEC-08
# 99998                             31-DEC-13
# 99999                             31-MAR-09
# 100000                            30-SEP-14
# 100001                            31-DEC-07
#
#                                                        17  \
# 0                            SDW_VIOL_ENFORCEMENT.SOURCES
# 1       Discharge from metal refineries and agricultur...
# 2                     Discharge from petroleum refineries
# 3                     Discharge from petroleum refineries
# 4       Leaching of soil fumigant used on rice and alf...
# ...                                                   ...
# 99997   Discharge from factories; leaching from gas st...
# 99998   Discharge from factories; leaching from gas st...
# 99999   Discharge from factories; leaching from gas st...
# 100000  Discharge from factories; leaching from gas st...
# 100001  Discharge from factories; leaching from gas st...
#
#                                                        18  \
# 0                         SDW_VIOL_ENFORCEMENT.DEFINITION
# 1       Hexachlorobenzene, a synthetic organic chemica...
# 2       Ethylbenzene is a colorless organic liquid wit...
# 3       Ethylbenzene is a colorless organic liquid wit...
# 4       Carbofuran is a white crystalline solid with a...
# ...                                                   ...
# 99997   Benzene, a volatile organic chemical, is a cle...
# 99998   Benzene, a volatile organic chemical, is a cle...
# 99999   Benzene, a volatile organic chemical, is a cle...
# 100000  Benzene, a volatile organic chemical, is a cle...
# 100001  Benzene, a volatile organic chemical, is a cle...
#
#                                                        19    20
# 0                     SDW_VIOL_ENFORCEMENT.HEALTH_EFFECTS
# 1       Liver or kidney problems; reproductive difficu...  None
# 2                               Liver or kidneys problems  None
# 3                               Liver or kidneys problems  None
# 4       Problems with blood, nervous system, or reprod...  None
# ...                                                   ...   ...
# 99997   Anemia; decrease in blood platelets; increased...  None
# 99998   Anemia; decrease in blood platelets; increased...  None
# 99999   Anemia; decrease in blood platelets; increased...  None
# 100000  Anemia; decrease in blood platelets; increased...  None
# 100001  Anemia; decrease in blood platelets; increased...  None
#
# [100002 rows x 21 columns]

# %%
#Chagning main csv
epa_try =  epa_csv

# %%
#Renaming the columns with the first row
epa_try.rename(columns=epa_try.iloc[0],inplace=True)

# %%
epa_try.head()
# Out:
#    SDW_VIOL_ENFORCEMENT.PWSID  SDW_VIOL_ENFORCEMENT.PWSNAME  \
# 0  SDW_VIOL_ENFORCEMENT.PWSID  SDW_VIOL_ENFORCEMENT.PWSNAME
# 1                   ID5160056              SPRINGDALE ACRES
# 2                   IN2493152   G & S REALTY PARTNERS, LLC.
# 3                   PA2450314            FEDEX FREIGHT EAST
# 4                   WY5601199   KENNINGTON SPRINGS PIPELINE
#
#    SDW_VIOL_ENFORCEMENT.STATE  SDW_VIOL_ENFORCEMENT.COUNTYSERVED  \
# 0  SDW_VIOL_ENFORCEMENT.STATE  SDW_VIOL_ENFORCEMENT.COUNTYSERVED
# 1                          ID                             CASSIA
# 2                          IN                             MARION
# 3                          PA                             MONROE
# 4                          WY
#
#    SDW_VIOL_ENFORCEMENT.VIOID  SDW_VIOL_ENFORCEMENT.CCODE  \
# 0  SDW_VIOL_ENFORCEMENT.VIOID  SDW_VIOL_ENFORCEMENT.CCODE
# 1                        8251                        2274
# 2                        6030                        2992
# 3                     1016111                        2992
# 4                        2325                        2046
#
#    SDW_VIOL_ENFORCEMENT.CNAME  SDW_VIOL_ENFORCEMENT.CTYPE  \
# 0  SDW_VIOL_ENFORCEMENT.CNAME  SDW_VIOL_ENFORCEMENT.CTYPE
# 1           HEXACHLOROBENZENE                         SOC
# 2                Ethylbenzene                         VOC
# 3                Ethylbenzene                         VOC
# 4                  Carbofuran                         SOC
#
#    SDW_VIOL_ENFORCEMENT.VCODE  SDW_VIOL_ENFORCEMENT.VNAME  ...  \
# 0  SDW_VIOL_ENFORCEMENT.VCODE  SDW_VIOL_ENFORCEMENT.VNAME  ...
# 1                          03         Monitoring, Regular  ...
# 2                          03         Monitoring, Regular  ...
# 3                          03         Monitoring, Regular  ...
# 4                          03         Monitoring, Regular  ...
#
#    SDW_VIOL_ENFORCEMENT.VIOLMEASURE  SDW_VIOL_ENFORCEMENT.ENFACTIONTYPE  \
# 0  SDW_VIOL_ENFORCEMENT.VIOLMEASURE  SDW_VIOL_ENFORCEMENT.ENFACTIONTYPE
# 1          Monitoring and Reporting                                 SIF
# 2          Monitoring and Reporting                                 SIF
# 3          Monitoring and Reporting                                 SIA
# 4          Monitoring and Reporting                                 SOX
#
#    SDW_VIOL_ENFORCEMENT.ENFACTIONNAME  SDW_VIOL_ENFORCEMENT.ENFDATE  \
# 0  SDW_VIOL_ENFORCEMENT.ENFACTIONNAME  SDW_VIOL_ENFORCEMENT.ENFDATE
# 1            St Public Notif received                     18-JUN-14
# 2            St Public Notif received                     10-JUN-10
# 3        St Violation/Reminder Notice                     25-AUG-10
# 4              St Compliance achieved                     24-OCT-11
#
#    SDW_VIOL_ENFORCEMENT.COMPPERBEGINDATE  SDW_VIOL_ENFORCEMENT.COMPPERENDDATE  \
# 0  SDW_VIOL_ENFORCEMENT.COMPPERBEGINDATE  SDW_VIOL_ENFORCEMENT.COMPPERENDDATE
# 1                              01-JAN-11                            31-DEC-13
# 2                              01-JAN-09                            31-DEC-09
# 3                              01-APR-10                            30-JUN-10
# 4                              01-JAN-08                            31-DEC-10
#
#                         SDW_VIOL_ENFORCEMENT.SOURCES  \
# 0                       SDW_VIOL_ENFORCEMENT.SOURCES
# 1  Discharge from metal refineries and agricultur...
# 2                Discharge from petroleum refineries
# 3                Discharge from petroleum refineries
# 4  Leaching of soil fumigant used on rice and alf...
#
#                      SDW_VIOL_ENFORCEMENT.DEFINITION  \
# 0                    SDW_VIOL_ENFORCEMENT.DEFINITION
# 1  Hexachlorobenzene, a synthetic organic chemica...
# 2  Ethylbenzene is a colorless organic liquid wit...
# 3  Ethylbenzene is a colorless organic liquid wit...
# 4  Carbofuran is a white crystalline solid with a...
#
#                  SDW_VIOL_ENFORCEMENT.HEALTH_EFFECTS
# 0                SDW_VIOL_ENFORCEMENT.HEALTH_EFFECTS
# 1  Liver or kidney problems; reproductive difficu...  None
# 2                          Liver or kidneys problems  None
# 3                          Liver or kidneys problems  None
# 4  Problems with blood, nervous system, or reprod...  None
#
# [5 rows x 21 columns]

# %%
#Deleting the first row 
epa_head = epa_try.drop(epa_try.index[0])

epa_head
# Out:
#        SDW_VIOL_ENFORCEMENT.PWSID      SDW_VIOL_ENFORCEMENT.PWSNAME  \
# 1                       ID5160056                  SPRINGDALE ACRES
# 2                       IN2493152       G & S REALTY PARTNERS, LLC.
# 3                       PA2450314                FEDEX FREIGHT EAST
# 4                       WY5601199       KENNINGTON SPRINGS PIPELINE
# 5                       IN5289019  TWIN FALLS MOBILE HOME COMMUNITY
# ...                           ...                               ...
# 99997                   CT0650102    HARTLAND ELEM SCH & TOWN BLDGS
# 99998                   WV3305535           HERNDON COMMUNITY WATER
# 99999                   VA6047255              GLENDALE SUBDIVISION
# 100000                  MA1033000              BLANDFORD WATER DEPT
# 100001                  ID2250026           HARPSTER WATER DISTRICT
#
#        SDW_VIOL_ENFORCEMENT.STATE SDW_VIOL_ENFORCEMENT.COUNTYSERVED  \
# 1                              ID                            CASSIA
# 2                              IN                            MARION
# 3                              PA                            MONROE
# 4                              WY
# 5                              IN                             WAYNE
# ...                           ...                               ...
# 99997                          CT
# 99998                          WV
# 99999                          VA                          CULPEPER
# 100000                         MA
# 100001                         ID                             IDAHO
#
#        SDW_VIOL_ENFORCEMENT.VIOID SDW_VIOL_ENFORCEMENT.CCODE  \
# 1                            8251                       2274
# 2                            6030                       2992
# 3                         1016111                       2992
# 4                            2325                       2046
# 5                            9530                       2046
# ...                           ...                        ...
# 99997                      379909                       2990
# 99998                     5204831                       2990
# 99999                          63                       2990
# 100000                         10                       2990
# 100001                      20308                       2990
#
#        SDW_VIOL_ENFORCEMENT.CNAME SDW_VIOL_ENFORCEMENT.CTYPE  \
# 1               HEXACHLOROBENZENE                        SOC
# 2                    Ethylbenzene                        VOC
# 3                    Ethylbenzene                        VOC
# 4                      Carbofuran                        SOC
# 5                      Carbofuran                        SOC
# ...                           ...                        ...
# 99997                     Benzene                        VOC
# 99998                     Benzene                        VOC
# 99999                     Benzene                        VOC
# 100000                    Benzene                        VOC
# 100001                    Benzene                        VOC
#
#        SDW_VIOL_ENFORCEMENT.VCODE SDW_VIOL_ENFORCEMENT.VNAME  ...  \
# 1                              03        Monitoring, Regular  ...
# 2                              03        Monitoring, Regular  ...
# 3                              03        Monitoring, Regular  ...
# 4                              03        Monitoring, Regular  ...
# 5                              03        Monitoring, Regular  ...
# ...                           ...                        ...  ...
# 99997                          03        Monitoring, Regular  ...
# 99998                          03        Monitoring, Regular  ...
# 99999                          03        Monitoring, Regular  ...
# 100000                         03        Monitoring, Regular  ...
# 100001                         03        Monitoring, Regular  ...
#
#        SDW_VIOL_ENFORCEMENT.VIOLMEASURE SDW_VIOL_ENFORCEMENT.ENFACTIONTYPE  \
# 1              Monitoring and Reporting                                SIF
# 2              Monitoring and Reporting                                SIF
# 3              Monitoring and Reporting                                SIA
# 4              Monitoring and Reporting                                SOX
# 5              Monitoring and Reporting                                SFJ
# ...                                 ...                                ...
# 99997          Monitoring and Reporting                                SIE
# 99998          Monitoring and Reporting                                SIE
# 99999          Monitoring and Reporting                                SIE
# 100000         Monitoring and Reporting                                SFL
# 100001         Monitoring and Reporting                                SOX
#
#        SDW_VIOL_ENFORCEMENT.ENFACTIONNAME SDW_VIOL_ENFORCEMENT.ENFDATE  \
# 1                St Public Notif received                    18-JUN-14
# 2                St Public Notif received                    10-JUN-10
# 3            St Violation/Reminder Notice                    25-AUG-10
# 4                  St Compliance achieved                    24-OCT-11
# 5                    St Formal NOV issued                    28-JAN-11
# ...                                   ...                          ...
# 99997           St Public Notif requested                    09-MAR-09
# 99998           St Public Notif requested                    13-FEB-14
# 99999           St Public Notif requested                    16-DEC-09
# 100000         St AO (w/o penalty) issued                    07-NOV-14
# 100001             St Compliance achieved                    19-MAR-10
#
#        SDW_VIOL_ENFORCEMENT.COMPPERBEGINDATE  \
# 1                                  01-JAN-11
# 2                                  01-JAN-09
# 3                                  01-APR-10
# 4                                  01-JAN-08
# 5                                  01-JAN-09
# ...                                      ...
# 99997                              01-OCT-08
# 99998                              01-OCT-13
# 99999                              01-JAN-09
# 100000                             01-JUL-14
# 100001                             01-JAN-05
#
#        SDW_VIOL_ENFORCEMENT.COMPPERENDDATE  \
# 1                                31-DEC-13
# 2                                31-DEC-09
# 3                                30-JUN-10
# 4                                31-DEC-10
# 5                                31-DEC-09
# ...                                    ...
# 99997                            31-DEC-08
# 99998                            31-DEC-13
# 99999                            31-MAR-09
# 100000                           30-SEP-14
# 100001                           31-DEC-07
#
#                              SDW_VIOL_ENFORCEMENT.SOURCES  \
# 1       Discharge from metal refineries and agricultur...
# 2                     Discharge from petroleum refineries
# 3                     Discharge from petroleum refineries
# 4       Leaching of soil fumigant used on rice and alf...
# 5       Leaching of soil fumigant used on rice and alf...
# ...                                                   ...
# 99997   Discharge from factories; leaching from gas st...
# 99998   Discharge from factories; leaching from gas st...
# 99999   Discharge from factories; leaching from gas st...
# 100000  Discharge from factories; leaching from gas st...
# 100001  Discharge from factories; leaching from gas st...
#
#                           SDW_VIOL_ENFORCEMENT.DEFINITION  \
# 1       Hexachlorobenzene, a synthetic organic chemica...
# 2       Ethylbenzene is a colorless organic liquid wit...
# 3       Ethylbenzene is a colorless organic liquid wit...
# 4       Carbofuran is a white crystalline solid with a...
# 5       Carbofuran is a white crystalline solid with a...
# ...                                                   ...
# 99997   Benzene, a volatile organic chemical, is a cle...
# 99998   Benzene, a volatile organic chemical, is a cle...
# 99999   Benzene, a volatile organic chemical, is a cle...
# 100000  Benzene, a volatile organic chemical, is a cle...
# 100001  Benzene, a volatile organic chemical, is a cle...
#
#                       SDW_VIOL_ENFORCEMENT.HEALTH_EFFECTS
# 1       Liver or kidney problems; reproductive difficu...  None
# 2                               Liver or kidneys problems  None
# 3                               Liver or kidneys problems  None
# 4       Problems with blood, nervous system, or reprod...  None
# 5       Problems with blood, nervous system, or reprod...  None
# ...                                                   ...   ...
# 99997   Anemia; decrease in blood platelets; increased...  None
# 99998   Anemia; decrease in blood platelets; increased...  None
# 99999   Anemia; decrease in blood platelets; increased...  None
# 100000  Anemia; decrease in blood platelets; increased...  None
# 100001  Anemia; decrease in blood platelets; increased...  None
#
# [100001 rows x 21 columns]

# %%
#census_data_income

# %% [markdown]
# ##Cleaning EPA Data

# %%
#Displaying EPA Data Columns for Reference

epa_head.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-43aeefdb57ea> in <module>
#       1 #Displaying EPA Data Columns for Reference
#       2
# ----> 3 epa_head.columns
#
# NameError: name 'epa_head' is not defined

# %%
#Selection of pertinent columns
epa_data_info = epa_head[["SDW_VIOL_ENFORCEMENT.STATE", 
                         "SDW_VIOL_ENFORCEMENT.COUNTYSERVED", 
                         "SDW_VIOL_ENFORCEMENT.CNAME", 
                         "SDW_VIOL_ENFORCEMENT.SOURCES", 
                         "SDW_VIOL_ENFORCEMENT.DEFINITION", 
                         "SDW_VIOL_ENFORCEMENT.HEALTH_EFFECTS"]]

epa_data_info.head()
# Out:
#   SDW_VIOL_ENFORCEMENT.STATE SDW_VIOL_ENFORCEMENT.COUNTYSERVED  \
# 1                         ID                            CASSIA
# 2                         IN                            MARION
# 3                         PA                            MONROE
# 4                         WY
# 5                         IN                             WAYNE
#
#   SDW_VIOL_ENFORCEMENT.CNAME  \
# 1          HEXACHLOROBENZENE
# 2               Ethylbenzene
# 3               Ethylbenzene
# 4                 Carbofuran
# 5                 Carbofuran
#
#                         SDW_VIOL_ENFORCEMENT.SOURCES  \
# 1  Discharge from metal refineries and agricultur...
# 2                Discharge from petroleum refineries
# 3                Discharge from petroleum refineries
# 4  Leaching of soil fumigant used on rice and alf...
# 5  Leaching of soil fumigant used on rice and alf...
#
#                      SDW_VIOL_ENFORCEMENT.DEFINITION  \
# 1  Hexachlorobenzene, a synthetic organic chemica...
# 2  Ethylbenzene is a colorless organic liquid wit...
# 3  Ethylbenzene is a colorless organic liquid wit...
# 4  Carbofuran is a white crystalline solid with a...
# 5  Carbofuran is a white crystalline solid with a...
#
#                  SDW_VIOL_ENFORCEMENT.HEALTH_EFFECTS
# 1  Liver or kidney problems; reproductive difficu...
# 2                          Liver or kidneys problems
# 3                          Liver or kidneys problems
# 4  Problems with blood, nervous system, or reprod...
# 5  Problems with blood, nervous system, or reprod...

# %%
#Renaming of Columns

epa_data_clean = epa_data_info.rename(columns={"SDW_VIOL_ENFORCEMENT.STATE": "State",
                              "SDW_VIOL_ENFORCEMENT.COUNTYSERVED": "County",
                               "SDW_VIOL_ENFORCEMENT.SOURCES": "Violation Source",
                              "SDW_VIOL_ENFORCEMENT.CNAME": "Chemical Name",
                              "SDW_VIOL_ENFORCEMENT.DEFINITION": "Chemical Definition",
                               "SDW_VIOL_ENFORCEMENT.HEALTH_EFFECTS": "Health Effects"})
epa_data_clean
# Out:
#        State    County      Chemical Name  \
# 1         ID    CASSIA  HEXACHLOROBENZENE
# 2         IN    MARION       Ethylbenzene
# 3         PA    MONROE       Ethylbenzene
# 4         WY                   Carbofuran
# 5         IN     WAYNE         Carbofuran
# ...      ...       ...                ...
# 99997     CT                      Benzene
# 99998     WV                      Benzene
# 99999     VA  CULPEPER            Benzene
# 100000    MA                      Benzene
# 100001    ID     IDAHO            Benzene
#
#                                          Violation Source  \
# 1       Discharge from metal refineries and agricultur...
# 2                     Discharge from petroleum refineries
# 3                     Discharge from petroleum refineries
# 4       Leaching of soil fumigant used on rice and alf...
# 5       Leaching of soil fumigant used on rice and alf...
# ...                                                   ...
# 99997   Discharge from factories; leaching from gas st...
# 99998   Discharge from factories; leaching from gas st...
# 99999   Discharge from factories; leaching from gas st...
# 100000  Discharge from factories; leaching from gas st...
# 100001  Discharge from factories; leaching from gas st...
#
#                                       Chemical Definition  \
# 1       Hexachlorobenzene, a synthetic organic chemica...
# 2       Ethylbenzene is a colorless organic liquid wit...
# 3       Ethylbenzene is a colorless organic liquid wit...
# 4       Carbofuran is a white crystalline solid with a...
# 5       Carbofuran is a white crystalline solid with a...
# ...                                                   ...
# 99997   Benzene, a volatile organic chemical, is a cle...
# 99998   Benzene, a volatile organic chemical, is a cle...
# 99999   Benzene, a volatile organic chemical, is a cle...
# 100000  Benzene, a volatile organic chemical, is a cle...
# 100001  Benzene, a volatile organic chemical, is a cle...
#
#                                            Health Effects
# 1       Liver or kidney problems; reproductive difficu...
# 2                               Liver or kidneys problems
# 3                               Liver or kidneys problems
# 4       Problems with blood, nervous system, or reprod...
# 5       Problems with blood, nervous system, or reprod...
# ...                                                   ...
# 99997   Anemia; decrease in blood platelets; increased...
# 99998   Anemia; decrease in blood platelets; increased...
# 99999   Anemia; decrease in blood platelets; increased...
# 100000  Anemia; decrease in blood platelets; increased...
# 100001  Anemia; decrease in blood platelets; increased...
#
# [100001 rows x 6 columns]

# %%
#Reordering of Columns

epa_data_clean2 = epa_data_clean[['State', 'County', 'Violation Source', 'Chemical Name', 'Chemical Definition', 'Health Effects']]

epa_data_clean2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-028adf40acdf> in <module>
#       1 #Reordering of Columns
#       2
# ----> 3 epa_data_clean2 = epa_data_clean[['State', 'County', 'Violation Source', 'Chemical Name', 'Chemical Definition', 'Health Effects']]
#       4
#       5 epa_data_clean2.head()
#
# NameError: name 'epa_data_clean' is not defined

# %%
#Deletion of rows without county name

epa_data_clean3 = epa_data_clean2[epa_data_clean2.County != ""]

epa_data_clean3
# Out:
#        State      County                                   Violation Source  \
# 1         ID      CASSIA  Discharge from metal refineries and agricultur...
# 2         IN      MARION                Discharge from petroleum refineries
# 3         PA      MONROE                Discharge from petroleum refineries
# 5         IN       WAYNE  Leaching of soil fumigant used on rice and alf...
# 6         MT    FLATHEAD  Leaching of soil fumigant used on rice and alf...
# ...      ...         ...                                                ...
# 99993     WV     WYOMING  Discharge from factories; leaching from gas st...
# 99994     NC     CASWELL  Discharge from factories; leaching from gas st...
# 99996     PA  SCHUYLKILL  Discharge from factories; leaching from gas st...
# 99999     VA    CULPEPER  Discharge from factories; leaching from gas st...
# 100001    ID       IDAHO  Discharge from factories; leaching from gas st...
#
#             Chemical Name                                Chemical Definition  \
# 1       HEXACHLOROBENZENE  Hexachlorobenzene, a synthetic organic chemica...
# 2            Ethylbenzene  Ethylbenzene is a colorless organic liquid wit...
# 3            Ethylbenzene  Ethylbenzene is a colorless organic liquid wit...
# 5              Carbofuran  Carbofuran is a white crystalline solid with a...
# 6              Carbofuran  Carbofuran is a white crystalline solid with a...
# ...                   ...                                                ...
# 99993             Benzene  Benzene, a volatile organic chemical, is a cle...
# 99994             Benzene  Benzene, a volatile organic chemical, is a cle...
# 99996             Benzene  Benzene, a volatile organic chemical, is a cle...
# 99999             Benzene  Benzene, a volatile organic chemical, is a cle...
# 100001            Benzene  Benzene, a volatile organic chemical, is a cle...
#
#                                            Health Effects
# 1       Liver or kidney problems; reproductive difficu...
# 2                               Liver or kidneys problems
# 3                               Liver or kidneys problems
# 5       Problems with blood, nervous system, or reprod...
# 6       Problems with blood, nervous system, or reprod...
# ...                                                   ...
# 99993   Anemia; decrease in blood platelets; increased...
# 99994   Anemia; decrease in blood platelets; increased...
# 99996   Anemia; decrease in blood platelets; increased...
# 99999   Anemia; decrease in blood platelets; increased...
# 100001  Anemia; decrease in blood platelets; increased...
#
# [70175 rows x 6 columns]

# %%
#Reset index
epa_data_clean3.reset_index(drop=True)
# Out:
#       State      County                                   Violation Source  \
# 0        ID      CASSIA  Discharge from metal refineries and agricultur...
# 1        IN      MARION                Discharge from petroleum refineries
# 2        PA      MONROE                Discharge from petroleum refineries
# 3        IN       WAYNE  Leaching of soil fumigant used on rice and alf...
# 4        MT    FLATHEAD  Leaching of soil fumigant used on rice and alf...
# ...     ...         ...                                                ...
# 70170    WV     WYOMING  Discharge from factories; leaching from gas st...
# 70171    NC     CASWELL  Discharge from factories; leaching from gas st...
# 70172    PA  SCHUYLKILL  Discharge from factories; leaching from gas st...
# 70173    VA    CULPEPER  Discharge from factories; leaching from gas st...
# 70174    ID       IDAHO  Discharge from factories; leaching from gas st...
#
#            Chemical Name                                Chemical Definition  \
# 0      HEXACHLOROBENZENE  Hexachlorobenzene, a synthetic organic chemica...
# 1           Ethylbenzene  Ethylbenzene is a colorless organic liquid wit...
# 2           Ethylbenzene  Ethylbenzene is a colorless organic liquid wit...
# 3             Carbofuran  Carbofuran is a white crystalline solid with a...
# 4             Carbofuran  Carbofuran is a white crystalline solid with a...
# ...                  ...                                                ...
# 70170            Benzene  Benzene, a volatile organic chemical, is a cle...
# 70171            Benzene  Benzene, a volatile organic chemical, is a cle...
# 70172            Benzene  Benzene, a volatile organic chemical, is a cle...
# 70173            Benzene  Benzene, a volatile organic chemical, is a cle...
# 70174            Benzene  Benzene, a volatile organic chemical, is a cle...
#
#                                           Health Effects
# 0      Liver or kidney problems; reproductive difficu...
# 1                              Liver or kidneys problems
# 2                              Liver or kidneys problems
# 3      Problems with blood, nervous system, or reprod...
# 4      Problems with blood, nervous system, or reprod...
# ...                                                  ...
# 70170  Anemia; decrease in blood platelets; increased...
# 70171  Anemia; decrease in blood platelets; increased...
# 70172  Anemia; decrease in blood platelets; increased...
# 70173  Anemia; decrease in blood platelets; increased...
# 70174  Anemia; decrease in blood platelets; increased...
#
# [70175 rows x 6 columns]
